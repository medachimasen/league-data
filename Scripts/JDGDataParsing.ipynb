# %%
import pandas as pd
import numpy as np

# %%
path = '../Processed/2020/JD Gaming/JD Gaming.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#       Unnamed: 0     gameid datacompleteness  \
# 0            216  5658-7257         complete
# 1            217  5658-7257         complete
# 2            218  5658-7257         complete
# 3            219  5658-7257         complete
# 4            220  5658-7257         complete
# ...          ...        ...              ...
# 1183       65263  6686-8955          partial
# 1184       65264  6686-8955          partial
# 1185       65265  6686-8955          partial
# 1186       65266  6686-8955          partial
# 1187       65267  6686-8955          partial
#
#                                               url league  year   split  \
# 0     https://lpl.qq.com/es/stats.shtml?bmid=5658    LPL  2020  Spring
# 1     https://lpl.qq.com/es/stats.shtml?bmid=5658    LPL  2020  Spring
# 2     https://lpl.qq.com/es/stats.shtml?bmid=5658    LPL  2020  Spring
# 3     https://lpl.qq.com/es/stats.shtml?bmid=5658    LPL  2020  Spring
# ...
